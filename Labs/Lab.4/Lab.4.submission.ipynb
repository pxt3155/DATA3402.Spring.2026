# %% [markdown]
# # Lab 4- Object Oriented Programming
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
class counter:
    def __init__(self, max_val):
        self.max_val = max_val
        self.value = 0  ##counter = 0
    
    def increment(self):
        if self.value < self.max_val:
            self.value = self.value + 1
        else:
            print("Error: counter is at max value")
            
    def reset(self):
        self.value = 0
        
    def return_value(self):
        return self.value

# %%
x = counter(3)
print("Initial Value: ", x.return_value())

x.increment()
print("After 1 incriment: ", x.return_value())
x.increment()
x.increment()
x.increment()
x.reset()
print("after reseting: ", x.return_value())
# Out:
# Initial Value:  0
# After 1 incriment:  1
# Error: counter is at max value
# after reseting:  0

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
class counter:
    def __init__(self, max_val):
        self.__max_val = max_val
        self.__value = 0  ##counter = 0
    
    def increment(self):
        if self.__value < self.__max_val:
            self.__value = self.__value + 1
        else:
            print("Error: counter is at max value")
            
    def reset(self):
        self.__value = 0
        
    def return_value(self):
        return self.__value
    
    def return_max_val(self):
        return self.__max_val
    
    def is_it_max(self):
        if self.__value == self.__max_val:
            return True
        else:
            return False

# %%
x = counter(4)

print("Initial value: ", x.return_value())
print("Max value: ", x.return_max_val())
print("Is it at the max value: ", x.is_it_max())

x.increment()
x.increment()
print("Current value: ", x.return_value())
print("Is it at the max value: ", x.is_it_max())

x.increment()
x.increment()
x.increment()
x.reset()
print("after reseting: ", x.return_value())
# Out:
# Initial value:  0
# Max value:  4
# Is it at the max value:  False
# Current value:  2
# Is it at the max value:  False
# Error: counter is at max value
# after reseting:  0

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class rectangle:
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y
        
    def length(self):
        return self.__length
    
    def width(self):
        return self.__width
    
    def x(self):
        return self.__x
    
    def y(self):
        return self.__y
    
    def area(self):
        return (self.__length*self.__width)
    
    def perimeter(self):
        return 2*(self.__length + self.__width)

# %%
R = rectangle(5,3,2,4)

print("Length: ", R.length())
print("Width: ", R.width())
print("X: ", R.x())
print("Y: ", R.y())
print("Area: ", R.area())
print("Perimeter: ", R.perimeter())
# Out:
# Length:  5
# Width:  3
# X:  2
# Y:  4
# Area:  15
# Perimeter:  16

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class circle:
    
    def __init__(self, radius, x, y):
        self.__radius=radius
        self.__x = x
        self.__y = y    
    def radius(self):
        return self.__radius
    
    def x(self):
        return self.__x
    
    def y(self):
        return self.__y
    
    def area(self):
        return 3.14*(self.__radius*self.__radius)
    
    def perimeter(self):
        return (2*3.14*self.__radius)

# %%
test=circle(4,1,3)

print("Radius:", test.radius())
print("X:", test.x())
print("Y:", test.y())
print("Area:", test.area())
print("Perimeter:", test.perimeter())
# Out:
# Radius: 4
# X: 1
# Y: 3
# Area: 50.24
# Perimeter: 25.12

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement your regtangle and circule classes to inherit from the base class and overload the functions accordingly.

# %%
##didn't fully understand what the question was asking so consulted LLM to get an outline for the answer
#1. create base class (shape)
#2. make rectangle inherit from the class shape (keeping all data members private)
#   (override: area() → length * width; perimeter() → 2 * (length + width))
#3. do the same for circle
#   (override: area() → 3.14 * r * r; perimeter() → 2 * 3.14 * r)

##didn't understand what the base class would include so asked LLM about it

class shape:
    def area(self):  #a method that both rectangle and circle
        print("not implemented") #since base clss doesn't know how to compute it
    def perimeter(self):
        print("not implemented")

class rectangle:
    def __init__(self, length, width, x, y):
        self.__length=length
        self.__width=width
        self.__x=x
        self.__y=y
        
    def length(self):
        return self.__length
    
    def width(self):
        return self.__width
    
    def x(self):
        return self.__x
    
    def y(self):
        return self.__y
    
    def area(self):
        return (self.__length*self.__width)
    
    def perimeter(self):
        return 2*(self.__length + self.__width)
    
class circle:    
    def __init__(self, radius, x, y):
        self.__radius=radius
        self.__x = x
        self.__y = y    
    def radius(self):
        return self.__radius
    
    def x(self):
        return self.__x
    
    def y(self):
        return self.__y
    
    def area(self):
        return 3.14*(self.__radius*self.__radius)
    
    def perimeter(self):
        return (2*3.14*self.__radius)

# %%
s = shape()
print("Base class area test:")
s.area()              
print("Base class perimeter test:")
s.perimeter()        

R = rectangle(5,3,2,4)

print("Length: ", R.length())
print("Width: ", R.width())
print("X: ", R.x())
print("Y: ", R.y())

print("Area: ", R.area())
print("Perimeter: ", R.perimeter())

test=circle(4,1,3)

print("Radius:", test.radius())
print("X:", test.x())
print("Y:", test.y())

print("Area:", test.area())
print("Perimeter:", test.perimeter())
# Out:
# Base class area test:
# not implemented
# Base class perimeter test:
# not implemented
# Length:  5
# Width:  3
# X:  2
# Y:  4
# Area:  15
# Perimeter:  16
# Radius: 4
# X: 1
# Y: 3
# Area: 50.24
# Perimeter: 25.12

# %% [markdown]
# 6. Implement a triangle class analogous to the rectangle and circle in question 5.

# %%
class Triangle(shape):
    
    def __init__(self, a, b, c, base, height, x, y):
        self.__a=a
        self.__b=b
        self.__c=c
        self.__base=base
        self.__height=height
        self.__x=x
        self.__y=y
    
    def a(self):
        return self.__a
    
    def b(self):
        return self.__b
    
    def c(self):
        return self.__c
    
    def base(self):
        return self.__base
    
    def height(self):
        return self.__height
    
    def x(self):
        return self.__x
    
    def y(self):
        return self.__y
    
    def area(self):
        return (0.5*self.__base*self.__height)
    
    def perimeter(self):
        return (self.__a+self.__b+self.__c)

# %%
t=Triangle(3, 4, 5, 4, 3, 1, 2)
print("Side a:", t.a())
print("Side b:", t.b())
print("Side c:", t.c())
print("Base:", t.base())
print("Height:", t.height())
print("X:", t.x())
print("Y:", t.y())
print("Area:", t.area())        
print("Perimeter:", t.perimeter())
# Out:
# Side a: 3
# Side b: 4
# Side c: 5
# Base: 4
# Height: 3
# X: 1
# Y: 2
# Area: 6.0
# Perimeter: 12

# %% [markdown]
# 7. Add a function to the object classes, including the base, that returns a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
##asked LLM to give outline for this
#outline:
#1. make base class (shape): add method get_points(); print "Not implemented"; ccts as virtual method
#2. Rectangle: Override get_points(); Return list of 4 corner (x, y) pairs
#3. Circle: Override get_points(); Return up to 8 points around circle
#4. Triangle: Override get_points(); Return 3 vertex points

class shape:    
    def area(self):
        print("Not implemented")   
        
    def perimeter(self):
        print("Not implemented")    
        
    def points(self):
        print("Not implemented")
        return[]

class rectangle:
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y
        
    def length(self):
        return self.__length
    
    def width(self):
        return self.__width
    
    def x(self):
        return self.__x
    
    def y(self):
        return self.__y
    
    def area(self):
        return (self.__length*self.__width)
    
    def perimeter(self):
        return 2*(self.__length + self.__width)
    
    def points(self):
        points = []
        x1=self.__x
        y1=self.__y
    
        x2=self.__x + self.__length
        y2=self.__y
    
        x3=self.__x + self.__length
        y3=self.__y + self.__width
    
        x4=self.__x
        y4=self.__y + self.__width
    
        points.append((x1, y1))
        points.append((x2, y2))
        points.append((x3, y3))
        points.append((x4, y4))
    
        return points

class circle:
    def __init__(self, radius, x, y):
        self.__radius=radius
        self.__x=x
        self.__y=y    
    def radius(self):
        return self.__radius
    
    def x(self):
        return self.__x
    
    def y(self):
        return self.__y
    
    def area(self):
        return 3.14*(self.__radius*self.__radius)
    
    def perimeter(self):
        return (2*3.14*self.__radius)
    
    def points(self):
        points=[]
    
        r=self.__radius
        x=self.__x
        y=self.__y
    
        points.append((x+r, y)) #right
        points.append((x-r, y)) #left
        points.append((x, y+r)) #top
        points.append((x, y-r)) #bottom    
        return points
    
class triangle:
    def __init__(self, a, b, c, base, height, x, y):
        self.__a=a
        self.__b=b
        self.__c=c
        self.__base=base
        self.__height=height
        self.__x=x
        self.__y=y
    
    def a(self):
        return self.__a
    
    def b(self):
        return self.__b
    
    def c(self):
        return self.__c
    
    def base(self):
        return self.__base
    
    def height(self):
        return self.__height
    
    def x(self):
        return self.__x
    
    def y(self):
        return self.__y
    
    def area(self):
        return (0.5*self.__base*self.__height)
    
    def perimeter(self):
        return (self.__a+self.__b+self.__c)
    
    def points(self):
        points=[]
    
        x1=self.__x
        y1=self.__y
    
        x2=self.__x + self.__base
        y2=self.__y
    
        x3=self.__x
        y3=self.__y + self.__height
    
        points.append((x1, y1))
        points.append((x2, y2))
        points.append((x3, y3))
    
        return points

# %%
s=shape()
print("shape points:", s.points())

r=rectangle(5, 3, 2, 4)
print("rectangle points:", r.points())

c=circle(4, 1, 3)
print("circle points:", c.points())

t=triangle(3, 4, 5, 4, 3, 1, 2)
print("triangle points:", t.points())
# Out:
# Not implemented
# shape points: []
# rectangle points: [(2, 4), (7, 4), (7, 7), (2, 7)]
# circle points: [(5, 3), (-3, 3), (1, 7), (1, -1)]
# triangle points: [(1, 2), (5, 2), (1, 5)]

# %% [markdown]
# 8. Add a function to the object classes, including the base, that tests if a given set of $x$ and $y$ coordinates are inside of the object. You'll have to think through how to determine if a set of coordinates are inside an object for each object type.

# %%
#asked LLM for a short ouline
#outline:
#1. Add contains(x,y) in base shape → prints "Not implemented" and returns False
#2. Rectangle contains → check if point is between left/right and bottom/top edges
#3. Circle contains → check squared distance from center ≤ radius²
#4. Triangle contains → for your right-triangle, use bounding box + line test
#5. Test each class with inside + outside points

class shape:    
    def area(self):
        print("Not implemented")
    
    def perimeter(self):
        print("Not implemented")
    
    def points(self):
        print("Not implemented")
        return []
    
    def contains(self, x, y):
        print("Not implemented")
        return False


class rectangle:
    def __init__(self, length, width, x, y):
        self.__length=length
        self.__width=width
        self.__x=x
        self.__y=y
        
    def length(self):
        return self.__length
    
    def width(self):
        return self.__width
    
    def x(self):
        return self.__x
    
    def y(self):
        return self.__y
    
    def area(self):
        return self.__length*self.__width
    
    def perimeter(self):
        return 2*(self.__length+self.__width)
    
    def points(self):
        points=[]
        
        x1=self.__x
        y1=self.__y
    
        x2=self.__x+self.__length
        y2=self.__y
    
        x3=self.__x+self.__length
        y3=self.__y+self.__width
    
        x4=self.__x
        y4=self.__y+self.__width
    
        points.append((x1, y1))
        points.append((x2, y2))
        points.append((x3, y3))
        points.append((x4, y4))    
        return points
    
    def contains(self, x, y):
        if (x >= self.__x) and (x <= self.__x + self.__length) and (y >= self.__y) and (y <= self.__y + self.__width):
            ## to check if point (x,y) is inside or on the boundary of the rectangle
            return True
        else:
            return False


class circle:
    def __init__(self, radius, x, y):
        self.__radius=radius
        self.__x=x
        self.__y=y    
        
    def radius(self):
        return self.__radius
    
    def x(self):
        return self.__x
    
    def y(self):
        return self.__y
    
    def area(self):
        return 3.14*(self.__radius*self.__radius)
    
    def perimeter(self):
        return (2*3.14*self.__radius)
    
    def points(self):
        points=[]
    
        r=self.__radius
        x=self.__x
        y=self.__y
    
        points.append((x+r, y))  # right
        points.append((x-r, y))  # left
        points.append((x, y+r))  # top
        points.append((x, y-r))  # bottom    
        return points
    
    def contains(self, x, y):
        dx = x - self.__x
        dy = y - self.__y
        if (dx * dx + dy * dy) <= (self.__radius * self.__radius):
            return True
        else:
            return False


class triangle:
    def __init__(self, a, b, c, base, height, x, y):
        self.__a=a
        self.__b=b
        self.__c=c
        self.__base=base
        self.__height=height
        self.__x=x
        self.__y=y
    
    def a(self):
        return self.__a
    
    def b(self):
        return self.__b
    
    def c(self):
        return self.__c
    
    def base(self):
        return self.__base
    
    def height(self):
        return self.__height
    
    def x(self):
        return self.__x
    
    def y(self):
        return self.__y
    
    def area(self):
        return (0.5*self.__base*self.__height)
    
    def perimeter(self):
        return (self.__a+self.__b+self.__c)
    
    def points(self):
        points = []
    
        x1=self.__x
        y1=self.__y
    
        x2=self.__x+self.__base
        y2=self.__y
    
        x3=self.__x
        y3=self.__y+self.__height
    
        points.append((x1, y1))
        points.append((x2, y2))
        points.append((x3, y3))
    
        return points
    
    def contains(self, x, y):
        x0=self.__x
        y0=self.__y
        
        #outside bounding box
        if x < x0 or x > x0 + self.__base:
            return False
        if y < y0 or y > y0 + self.__height:
            return False
        
        #inside if under the diagonal
        if ((x - x0)/self.__base) + ((y - y0)/self.__height) <= 1:
            return True
        else:
            return False

# %%
s = shape()
print("shape contains (0,0):", s.contains(0, 0))   

r = rectangle(5, 3, 2, 4)
print("rectangle contains (3,5):", r.contains(3, 5))     
print("rectangle contains (10,5):", r.contains(10, 5))   

c = circle(4, 1, 3)
print("circle contains (1,3):", c.contains(1, 3))        
print("circle contains (6,3):", c.contains(6, 3))        

t = triangle(3, 4, 5, 4, 3, 1, 2)
print("triangle contains (1,2):", t.contains(1, 2))      
print("triangle contains (3,3):", t.contains(3, 3))      
print("triangle contains (5,5):", t.contains(5, 5))
# Out:
# Not implemented
# shape contains (0,0): False
# rectangle contains (3,5): True
# rectangle contains (10,5): False
# circle contains (1,3): True
# circle contains (6,3): False
# triangle contains (1,2): True
# triangle contains (3,3): True
# triangle contains (5,5): False

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
#outline:
#1. add overlaps(other) to the base class, print "not implemented"
#2. rectangle overlap for checking if bounding boxes intersect
#3. circle overlap for checking if the circles overlap (if distance bw centers <= sum of radii)
#4. triangle overlap for checking if bounding boxes overlap


class shape:    
    def area(self):
        print("Not implemented")    
    def perimeter(self):
        print("Not implemented")    
    def points(self):
        print("Not implemented")
        return []    
    def contains(self, x, y):
        print("Not implemented")
        return False    
    def overlaps(self, other):
        print("Not implemented")
        return False


class rectangle(shape):
    def __init__(self, length, width, x, y):
        self.__length=length
        self.__width=width
        self.__x=x
        self.__y=y
    
    def overlaps(self, other):
        if isinstance(other, rectangle):
            
            if (self.__x + self.__length < other.__x or
                other.__x + other.__length < self.__x or
                self.__y + self.__width < other.__y or
                other.__y + other.__width < self.__y):
                return False
            else:
                return True
        else:
            return False


class circle(shape):
    def __init__(self, radius, x, y):
        self.__radius=radius
        self.__x=x
        self.__y=y
    
    def overlaps(self, other):
        if isinstance(other, circle):
            
            dx=self.__x - other.__x
            dy=self.__y - other.__y
            
            distance_squared=dx*dx + dy*dy
            radius_sum=self.__radius + other.__radius
            
            if distance_squared <= radius_sum * radius_sum:
                return True
            else:
                return False
        else:
            return False


class triangle(shape):
    def __init__(self, base, height, x, y):
        self.__base=base
        self.__height=height
        self.__x=x
        self.__y=y
    
    def overlaps(self, other):
        if isinstance(other, triangle):
            
            if (self.__x + self.__base < other.__x or
                other.__x + other.__base < self.__x or
                self.__y + self.__height < other.__y or
                other.__y + other.__height < self.__y):
                return False
            else:
                return True
        else:
            return False

# %%
#asked LLM to give points to test with
# Rectangle tests
r1 = rectangle(4, 3, 0, 0)
r2 = rectangle(4, 3, 2, 1)   
r3 = rectangle(4, 3, 10, 10) 
print("Rectangle overlap (True):", r1.overlaps(r2))
print("Rectangle overlap (False):", r1.overlaps(r3))

# Circle tests
c1 = circle(3, 0, 0)
c2 = circle(3, 4, 0)   
c3 = circle(3, 10, 0)  
print("Circle overlap (True):", c1.overlaps(c2))
print("Circle overlap (False):", c1.overlaps(c3))

# Triangle tests
t1 = triangle(4, 3, 0, 0)
t2 = triangle(4, 3, 2, 1)    
t3 = triangle(4, 3, 10, 10)  
print("Triangle overlap (True):", t1.overlaps(t2))
print("Triangle overlap (False):", t1.overlaps(t3))
# Out:
# Rectangle overlap (True): True
# Rectangle overlap (False): False
# Circle overlap (True): True
# Circle overlap (False): False
# Triangle overlap (True): True
# Triangle overlap (False): False

# %% [markdown]
# 10. Copy the `Canvas` class from lecture to in a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %%
#For Q10, I created a paint.py module containing the canvas class, shape classes, paint_shape() function, and CompoundShape class. 
#I also made demo.py to import the module and demonstrate a simple drawing.

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %%
class RasterDrawing:    
    def __init__(self, width, height, bg=" "):        
        self.c=canvas(width, height, bg)        
        self.items=[]
        
    def add_shape(self, obj, char):        
        self.items.append((obj, char))
        
    def remove_shape(self, index):        
        if index >= 0 and index < len(self.items):            
            self.items.pop(index)    
    
    def paint(self):        
        self.c=canvas(self.c.width, self.c.height, self.c.bg)        
        i=0        
        
        while i<len(self.items):            
            obj=self.items[i][0]
            ch=self.items[i][1]            
            paint_shape(self.c, obj, ch)            
            i = i+1  
    
    def show(self):        
        self.c.show()

# %%
from paint import canvas, rectangle, circle, triangle, paint_shape

d=RasterDrawing(40, 20, " .")

r=rectangle(6, 4, 2, 2)
c1=circle(3, 15, 8)
t=triangle(5, 4, 25, 5)

d.add_shape(r, "#")
d.add_shape(c1, "o")
d.add_shape(t, "|")

print("FIRST DRAWING:")
d.paint()
d.show()


# modifying drawing
d.remove_shape(1)

new_c=circle(2, 30, 14)
d.add_shape(new_c, "*")

print("\n SECOND DRAWING:")
d.paint()
d.show()
# Out:
# FIRST DRAWING:
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#  . .# . . . . .# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#  . . . . . . . . . . . . . . .o . . . . . . . . .| . . . .| . . . . . . . . .
#  . .# . . . . .# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#  . . . . . . . . . . . .o . . . . .o . . . . . . . . . . . . . . . . . . . . .
#  . . . . . . . . . . . . . . . . . . . . . . . . .| . . . . . . . . . . . . . .
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# ...

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
class foo:
    def __init__(self,a,b=None):
        self.a=a
        self.b=b
        
    def __repr__(self):
        return "foo("+repr(self.a)+","+repr(self.b)+")"
    
    def save(self,filename):
        f=open(filename,"w")
        f.write(self.__repr__())
        f.close()
        
   
def foo_loader(filename):
    f=open(filename,"r")
    tmp=eval(f.read())
    f.close()
    return tmp

# %%
# Test
print(repr(foo(1,"hello")))
# Out:
# foo(1,'hello')

# %%
# Create an object and save it
ff=foo(1,"hello")
ff.save("Test.foo")

# %%
# Check contents of the saved file
# !cat Test.foo
# Out:
# foo(1,'hello')

# %%
# Load the object
ff_reloaded=foo_loader("Test.foo")
ff_reloaded
# Out:
# foo(1,'hello')

# %%
class rectangle(shape):
    def __init__(self, length, width, x, y):
        self.__length=length
        self.__width=width
        self.__x=x
        self.__y=y

    def points(self):
        pts=[]

        x1=self.__x
        y1=self.__y

        x2=self.__x + self.__length
        y2=self.__y

        x3=self.__x + self.__length
        y3=self.__y + self.__width

        x4=self.__x
        y4=self.__y + self.__width

        pts.append((x1, y1))
        pts.append((x2, y2))
        pts.append((x3, y3))
        pts.append((x4, y4))

        return pts

    def __repr__(self):
        return "rectangle(" + repr(self.__length) + "," + repr(self.__width) + "," + repr(self.__x) + "," + repr(self.__y) + ")"


class circle(shape):
    def __init__(self, radius, x, y):
        self.__radius=radius
        self.__x=x
        self.__y=y

    def points(self):
        pts=[]

        r=self.__radius
        x=self.__x
        y=self.__y

        pts.append((x+r, y))
        pts.append((x-r, y))
        pts.append((x, y+r))
        pts.append((x, y-r))

        return pts

    def __repr__(self):
        return "circle(" + repr(self.__radius) + "," + repr(self.__x) + "," + repr(self.__y) + ")"


class triangle(shape):
    def __init__(self, base, height, x, y):
        self.__base=base
        self.__height=height
        self.__x=x
        self.__y=y

    def points(self):
        pts=[]

        x1=self.__x
        y1=self.__y

        x2=self.__x + self.__base
        y2=self.__y

        x3=self.__x
        y3=self.__y + self.__height

        pts.append((x1, y1))
        pts.append((x2, y2))
        pts.append((x3, y3))

        return pts

    def __repr__(self):
        return "triangle(" + repr(self.__base) + "," + repr(self.__height) + "," + repr(self.__x) + "," + repr(self.__y) + ")"

# %%
from paint import canvas, rectangle, circle, triangle, RasterDrawing, load_raster

d = RasterDrawing(40, 20, ".")

d.add_shape(rectangle(6,4,2,2),"#")
d.add_shape(circle(3,15,8),"o")
d.add_shape(triangle(5,4,25,5),"^")

print("ORIGINAL DRAWING:")
d.paint()
d.show()


print("\nrepr(d):")
print(repr(d))


d.save("drawing.txt")

print("\nFILE CONTENTS:")
f = open("drawing.txt","r")
print(f.read())
f.close()


d2 = load_raster("drawing.txt")

print("\nRELOADED DRAWING:")
d2.paint()
d2.show()
# Out:
# ORIGINAL DRAWING:
# ........................................
# ........................................
# ..#.....#...............................
# ........................................
# ........................................
# ...............o.........^....^.........
# ..#.....#...............................
# ........................................
# ............o.....o.....................
# .........................^..............
# ........................................
# ...............o........................
# ........................................
# ........................................
# ........................................
# ........................................
# ........................................
# ........................................
# ........................................
# ........................................
#
# repr(d):
# ...
